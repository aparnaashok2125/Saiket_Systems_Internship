# %% [markdown]
# <a href="https://colab.research.google.com/github/aparnaashok2125/Saiket_Systems_Internship/blob/main/Data_Preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
import os
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ###Task 1 : Data Preparation

# %%
df = pd.read_csv('/content/Telco_Customer_Churn_Dataset  (1).csv')

# %%
df.drop('customerID', axis=1, inplace=True)

# %%
df.sample(10)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 783   Female              0      No         No       1          Yes
# 1       Male              0      No         No      34          Yes
# 4520    Male              0     Yes        Yes       1          Yes
# 5051    Male              0      No         No      56          Yes
# 371     Male              0      No         No       2          Yes
# 2556    Male              0     Yes         No      45          Yes
# 3532  Female              0      No         No      15          Yes
# 4702    Male              1      No         No      54           No
# 2819  Female              0      No         No       4          Yes
# 4468  Female              0      No         No      15          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 783                 No             DSL                   No
# 1                   No             DSL                  Yes
# 4520                No              No  No internet service
# 5051               Yes     Fiber optic                  Yes
# 371                Yes     Fiber optic                   No
# 2556               Yes     Fiber optic                  Yes
# 3532                No             DSL                   No
# 4702  No phone service             DSL                   No
# 2819                No             DSL                  Yes
# 4468               Yes              No  No internet service
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 783                    No                   No                  Yes
# 1                      No                  Yes                   No
# 4520  No internet service  No internet service  No internet service
# 5051                   No                   No                  Yes
# 371                    No                   No                   No
# 2556                   No                  Yes                   No
# 3532                   No                  Yes                   No
# 4702                  Yes                  Yes                   No
# 2819                  Yes                   No                   No
# 4468  No internet service  No internet service  No internet service
#
#               StreamingTV      StreamingMovies        Contract  \
# 783                    No                   No  Month-to-month
# 1                      No                   No        One year
# 4520  No internet service  No internet service  Month-to-month
# 5051                  Yes                  Yes  Month-to-month
# 371                   Yes                   No  Month-to-month
# 2556                   No                   No  Month-to-month
# 3532                   No                  Yes  Month-to-month
# 4702                  Yes                  Yes        One year
# 2819                   No                   No  Month-to-month
# 4468  No internet service  No internet service  Month-to-month
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 783               Yes           Electronic check           52.20         52.2
# 1                  No               Mailed check           56.95       1889.5
# 4520               No  Bank transfer (automatic)           19.95        19.95
# 5051              Yes               Mailed check          105.35      5794.45
# 371               Yes           Electronic check           85.65        181.5
# 2556              Yes               Mailed check           84.55      3713.95
# 3532              Yes           Electronic check           59.45       892.65
# 4702              Yes           Electronic check           55.45      2966.95
# 2819               No           Electronic check           55.20       220.65
# 4468              Yes    Credit card (automatic)           25.40        399.6
#
#      Churn
# 783    Yes
# 1       No
# 4520   Yes
# 5051    No
# 371    Yes
# 2556    No
# 3532   Yes
# 4702    No
# 2819    No
# 4468   Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   object
#  19  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
# As we can see there are 7043 entries
# there are no missing values

# %%
# Convert TotalCharges to float
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.duplicated().sum()
# Out:
# np.int64(22)

# %%
# There is no duplicate rows in the dataset

# %%
#remove duplicates
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# No null values in the dataset

# %%
#drop rows with missing values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (7010, 20)

# %% [markdown]
# ### Encoding Categorical columns

# %%
df_encoded = df.copy()

# %%
categorical_columns = df_encoded.select_dtypes(include=["object"]).columns
categorical_columns
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
categorical_columns = [col for col in categorical_columns if col not in ['Churn', 'gender','MultipleLines','InternetService','Contract','PaymentMethod']]
categorical_columns
# Out:
# ['Partner',
#  'Dependents',
#  'PhoneService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'PaperlessBilling']

# %%
# Convert all categorical columns
# "Yes" -> 1, "No" -> 0, "No internet service" -> -1
for col in categorical_columns:
    df_encoded[col] = df_encoded[col].apply(lambda x: 1 if x == "Yes" else (-1 if x == "No internet service" else 0))

# %%
# gender -> 1 for males, 0 for females
df_encoded['gender'] = df_encoded['gender'].apply(lambda x: 1 if x == "Male" else 0)
df_encoded.sample(10)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 5199       0              0        0           0      51             1
# 4926       1              0        1           0      62             1
# 708        1              0        1           0      29             1
# 2089       0              0        0           0      50             0
# 5914       1              0        1           1      25             1
# 3290       0              0        0           0       4             0
# 2385       0              0        0           1       3             0
# 5604       1              0        0           0      17             1
# 5707       0              0        0           0       2             1
# 4676       1              0        0           1      19             1
#
#          MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 5199               Yes     Fiber optic               0             1
# 4926                No             DSL               0             1
# 708                 No     Fiber optic               0             0
# 2089  No phone service             DSL               0             1
# 5914                No             DSL               1             0
# 3290  No phone service             DSL               1             0
# 2385  No phone service             DSL               0             1
# 5604                No     Fiber optic               0             0
# 5707                No             DSL               0             0
# 4676                No              No              -1            -1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 5199                 1            1            1                1
# 4926                 1            1            0                0
# 708                  1            0            0                0
# 2089                 1            1            0                0
# 5914                 0            1            0                0
# 3290                 1            0            0                0
# 2385                 0            0            0                0
# 5604                 0            0            0                0
# 5707                 0            0            0                0
# 4676                -1           -1           -1               -1
#
#             Contract  PaperlessBilling            PaymentMethod  \
# 5199        One year                 1         Electronic check
# 4926        Two year                 1  Credit card (automatic)
# 708   Month-to-month                 1  Credit card (automatic)
# 2089        Two year                 0  Credit card (automatic)
# 5914  Month-to-month                 0         Electronic check
# 3290  Month-to-month                 0             Mailed check
# 2385  Month-to-month                 0             Mailed check
# 5604  Month-to-month                 1         Electronic check
# 5707  Month-to-month                 0         Electronic check
# 4676  Month-to-month                 1         Electronic check
#
#       MonthlyCharges  TotalCharges Churn
# 5199          111.50       5703.25    No
# 4926           60.15       3753.20    No
# 708            75.30       2263.40    No
# 2089           39.70       1932.75    No
# 5914           54.30       1296.80    No
# 3290           35.00        135.75    No
# 2385           29.65         90.05    No
# 5604           70.80       1207.00    No
# 5707           45.55         84.40    No
# 4676           20.00        377.55    No

# %%
# MultipleLines -> 1 for yes, 0 for no, -1 for No phone service
df_encoded['MultipleLines'] = df_encoded['MultipleLines'].apply(lambda x: 1 if x == "Yes" else (-1 if x == "No phone service" else 0))
df_encoded.sample(10)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 2792       0              0        0           0      15             1
# 118        0              0        0           0      41             1
# 4248       0              0        1           0      56             1
# 2032       0              0        1           0      15             1
# 744        0              0        0           0       5             1
# 3434       0              0        0           0      11             1
# 3537       1              0        1           1      25             1
# 6904       0              1        0           0      64             0
# 3801       0              1        0           0      18             1
# 6071       1              0        1           1      72             1
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 2792              0             DSL               0             1
# 118               0              No              -1            -1
# 4248              1     Fiber optic               0             1
# 2032              0     Fiber optic               0             0
# 744               0             DSL               0             0
# 3434              0             DSL               1             0
# 3537              0             DSL               0             1
# 6904             -1             DSL               0             1
# 3801              1     Fiber optic               0             1
# 6071              1     Fiber optic               1             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 2792                 0            0            0                0
# 118                 -1           -1           -1               -1
# 4248                 1            1            0                0
# 2032                 0            0            1                1
# 744                  0            0            0                0
# 3434                 0            1            0                0
# 3537                 1            0            0                0
# 6904                 0            1            1                0
# 3801                 0            1            0                0
# 6071                 1            0            1                1
#
#             Contract  PaperlessBilling              PaymentMethod  \
# 2792  Month-to-month                 0           Electronic check
# 118         Two year                 0               Mailed check
# 4248  Month-to-month                 0           Electronic check
# 2032  Month-to-month                 0           Electronic check
# 744   Month-to-month                 1    Credit card (automatic)
# 3434        One year                 1               Mailed check
# 3537        One year                 0               Mailed check
# 6904  Month-to-month                 1           Electronic check
# 3801  Month-to-month                 1           Electronic check
# 6071        Two year                 1  Bank transfer (automatic)
#
#       MonthlyCharges  TotalCharges Churn
# 2792           48.85        736.80    No
# 118            20.65        835.15    No
# 4248           90.55       5116.60    No
# 2032           88.15       1390.60   Yes
# 744            44.05        202.15    No
# 3434           54.60        617.85    No
# 3537           53.65       1355.45    No
# 6904           43.85       2751.00    No
# 3801           85.45       1505.85   Yes
# 6071          105.55       7542.25    No

# %%
# label encoding to churn column as Yes to 1 and no to 0
label_encoder = LabelEncoder()
df_encoded["Churn"] = label_encoder.fit_transform(df["Churn"])
df_encoded.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 3880       1              0        1           1      26             1
# 3897       0              0        1           1      72             1
# 1929       1              0        1           1       1             1
# 1227       1              0        0           0      30             1
# 390        0              0        0           0      27             1
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 3880              1             DSL               0             0
# 3897              1     Fiber optic               1             1
# 1929              0     Fiber optic               0             0
# 1227              1     Fiber optic               1             1
# 390               1     Fiber optic               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 3880                 1            1            1                1
# 3897                 1            1            1                1
# 1929                 0            0            0                1
# 1227                 1            0            0                0
# 390                  0            0            1                1
#
#             Contract  PaperlessBilling              PaymentMethod  \
# 3880        One year                 1    Credit card (automatic)
# 3897        Two year                 1           Electronic check
# 1929  Month-to-month                 1           Electronic check
# 1227        One year                 0  Bank transfer (automatic)
# 390   Month-to-month                 1  Bank transfer (automatic)
#
#       MonthlyCharges  TotalCharges  Churn
# 3880           82.00       2083.10      0
# 3897          115.50       8425.15      0
# 1929           81.05         81.05      0
# 1227           90.40       2820.65      0
# 390            95.60       2595.25      0

# %%
# Unique categories of InternetService
df_encoded['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
# Encode DSL as 1 and Fiber optic as 2 and No as 0
df_encoded['InternetService'] = df_encoded['InternetService'].apply(lambda x: 1 if x == "DSL" else (2 if x == "Fiber optic" else 0))
df_encoded.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 2708       0              1        0           0      13             1
# 3861       0              0        0           1      26             1
# 908        0              0        0           1       8             1
# 6705       1              0        1           1      22             1
# 2585       0              0        0           0      37             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 2708              1                2               1             0
# 3861              0                2               0             1
# 908               0                0              -1            -1
# 6705              0                1               0             0
# 2585              0                0              -1            -1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 2708                 0            0            1                1
# 3861                 1            1            1                1
# 908                 -1           -1           -1               -1
# 6705                 0            1            0                0
# 2585                -1           -1           -1               -1
#
#             Contract  PaperlessBilling     PaymentMethod  MonthlyCharges  \
# 2708  Month-to-month                 1  Electronic check          100.80
# 3861        Two year                 1  Electronic check          105.45
# 908   Month-to-month                 0      Mailed check           19.95
# 6705  Month-to-month                 1  Electronic check           51.10
# 2585        Two year                 0      Mailed check           19.80
#
#       TotalCharges  Churn
# 2708        1308.1      1
# 3861        2715.3      0
# 908          170.9      0
# 6705        1232.9      0
# 2585         813.3      0

# %%
# Unique categories of Contract
df_encoded['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# Encoding Contract as 1 for Month-to-month, 12 for One year and 24 for Two year
df_encoded['Contract'] = df_encoded['Contract'].apply(lambda x: 1 if x == "Month-to-month" else (12 if x == "One year" else 24))
df_encoded.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 2831       0              1        1           0      12             1
# 6284       0              0        0           0      23             1
# 2759       1              0        0           0       1             1
# 4077       0              1        1           1      14             1
# 3367       1              0        0           0      52             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 2831              1                2               0             1
# 6284              1                2               0             0
# 2759              0                0              -1            -1
# 4077              1                2               0             0
# 3367              1                1               1             1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 2831                 1            0            1                0         1
# 6284                 0            0            1                1         1
# 2759                -1           -1           -1               -1         1
# 4077                 0            0            1                1         1
# 3367                 1            1            1                1        24
#
#       PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 2831                 1           Electronic check           98.10
# 6284                 1           Electronic check           93.50
# 2759                 0  Bank transfer (automatic)           19.65
# 4077                 1           Electronic check           95.80
# 3367                 1               Mailed check           89.25
#
#       TotalCharges  Churn
# 2831       1060.20      1
# 6284       2341.55      0
# 2759         19.65      0
# 4077       1346.30      0
# 3367       4652.40      0

# %%
# Unique categories of PaymentMethod
df_encoded['PaymentMethod'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
# Encoding PaymentMethod as 1 for Electronic check, 2 for Mailed check, 3 for Bank transfer (automatic) and 4 for Credit card (automatic)
df_encoded['PaymentMethod'] = df_encoded['PaymentMethod'].apply(lambda x: 1 if x == "Electronic check" else (2 if x == "Mailed check" else (3 if x == "Bank transfer (automatic)" else 4)))
df_encoded.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 2829       1              1        0           0       8             1
# 722        0              0        1           1       4             1
# 5728       0              0        0           0      13             1
# 3938       0              0        0           0       2             1
# 5953       1              0        0           0       1             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 2829              0                2               0             0
# 722               1                2               0             0
# 5728              1                2               0             1
# 3938              0                1               1             0
# 5953              0                1               1             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 2829                 0            0            0                0         1
# 722                  0            0            0                1         1
# 5728                 1            1            0                0         1
# 3938                 0            0            0                0         1
# 5953                 0            0            0                0         1
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 2829                 1              1           69.70        560.85      1
# 722                  1              1           85.95        381.30      1
# 5728                 0              1           89.40       1132.35      1
# 3938                 0              2           50.95        123.05      0
# 5953                 1              2           50.70         50.70      0

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7010 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7010 non-null   int64
#  1   SeniorCitizen     7010 non-null   int64
#  2   Partner           7010 non-null   int64
#  3   Dependents        7010 non-null   int64
#  4   tenure            7010 non-null   int64
#  5   PhoneService      7010 non-null   int64
#  6   MultipleLines     7010 non-null   int64
#  7   InternetService   7010 non-null   int64
#  8   OnlineSecurity    7010 non-null   int64
#  9   OnlineBackup      7010 non-null   int64
#  10  DeviceProtection  7010 non-null   int64
#  11  TechSupport       7010 non-null   int64
#  12  StreamingTV       7010 non-null   int64
#  13  StreamingMovies   7010 non-null   int64
#  14  Contract          7010 non-null   int64
#  15  PaperlessBilling  7010 non-null   int64
#  16  PaymentMethod     7010 non-null   int64
#  17  MonthlyCharges    7010 non-null   float64
#  18  TotalCharges      7010 non-null   float64
#  19  Churn             7010 non-null   int64
# dtypes: float64(2), int64(18)
# memory usage: 1.1 MB

# %%
# Save the encoded dataframe to a CSV file
df_encoded.to_csv('/content/Telco_Customer_Churn_Dataset  (1).csv', index=False)
